# %%
import pickle
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


data_dict = pickle.load(open('./data.pickle', 'rb'))

data = np.asarray(data_dict['data'])
labels = np.asarray(data_dict['labels'])

x_train, x_test, y_train, y_test = train_test_split(
    data, labels, test_size=0.2, shuffle=True, stratify=labels
)

model = RandomForestClassifier(n_estimators=100)

model.fit(x_train, y_train)

y_predict = model.predict(x_test)

score = accuracy_score(y_predict, y_test)

print(f'Accuracy: {score * 100:.2f}%')

with open('model.p', 'wb') as f:
    pickle.dump({'model': model}, f)
# Out:
# Accuracy: 100.00%

# %%
from collections import Counter
print("Label distribution:", Counter(labels))
# Out:
# Label distribution: Counter({'0': 200, '1': 200, '2': 200, '3': 200, '4': 200, '5': 200, '6': 200, '7': 200, '8': 200, '9': 200, 'A': 200, 'B': 200, 'C': 200, 'D': 200, 'E': 200, 'F': 200, 'G': 200, 'H': 200, 'I': 200, 'J': 200, 'K': 200, 'L': 200, 'M': 200, 'N': 200, 'O': 200, 'P': 200, 'R': 200, 'S': 200, 'space': 200, 'T': 200, 'U': 200, 'V': 200, 'W': 200, 'X': 200, 'Y': 200, 'Z': 200, 'Q': 183})

# %%
print("Sample feature:", data[0])
# Out:
# Sample feature: [0.19391006 0.34707403 0.10061193 0.29212809 0.0483278  0.23336416
#  0.0106045  0.192415   0.         0.13705546 0.12566388 0.09784329
#  0.06974566 0.0340144  0.02559167 0.06914094 0.01520747 0.12562662
#  0.14675665 0.08474565 0.07703346 0.00658536 0.02139872 0.05380133
#  0.01388294 0.11552227 0.15935016 0.08722639 0.09202117 0.
#  0.03010362 0.0428313  0.01724738 0.09966612 0.15861684 0.10678369
#  0.09497839 0.05259502 0.04470325 0.07639718 0.03013611 0.11194646]

# %%
print("\n📊 Classification Report:")
print(classification_report(y_test, y_predict))


print("\n📉 Confusion Matrix:")
cm = confusion_matrix(y_test, y_predict)
print(cm)
# Out:
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#            8       1.00      1.00      1.00        40
#            9       1.00      1.00      1.00        40
#            A       1.00      1.00      1.00        40
#            B       1.00      1.00      1.00        40
#            C       1.00      1.00      1.00        40
#            D       1.00      1.00      1.00        40
#            E       1.00      1.00      1.00        40
#            F       1.00      1.00      1.00        40
# ...

# %%
"""from collections import defaultdict

x_train, x_test, y_train, y_test = [], [], [], []
label_indices = defaultdict(list)

# Group indices by each label
for i, label in enumerate(labels):
    label_indices[label].append(i)

# For each sign, first 80% is train, last 20% is test
for label, indices in label_indices.items():
    split_point = int(len(indices) * 0.8)
    
    # First 80% consecutive frames (Training)
    x_train.extend([data[i] for i in indices[:split_point]])
    y_train.extend([label] * split_point)
    
    # Last 20% consecutive frames (Testing)
    x_test.extend([data[i] for i in indices[split_point:]])
    y_test.extend([label] * (len(indices) - split_point))

x_train = np.asarray(x_train)
x_test = np.asarray(x_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)
"""
# Out:
# 'from collections import defaultdict\n\nx_train, x_test, y_train, y_test = [], [], [], []\nlabel_indices = defaultdict(list)\n\n# Group indices by each label\nfor i, label in enumerate(labels):\n    label_indices[label].append(i)\n\n# For each sign, first 80% is train, last 20% is test\nfor label, indices in label_indices.items():\n    split_point = int(len(indices) * 0.8)\n    \n    # First 80% consecutive frames (Training)\n    x_train.extend([data[i] for i in indices[:split_point]])\n    y_train.extend([label] * split_point)\n    \n    # Last 20% consecutive frames (Testing)\n    x_test.extend([data[i] for i in indices[split_point:]])\n    y_test.extend([label] * (len(indices) - split_point))\n\nx_train = np.asarray(x_train)\nx_test = np.asarray(x_test)\ny_train = np.asarray(y_train)\ny_test = np.asarray(y_test)\n'
